# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('imdb_movies_shows.csv')

# %%
df
# Out:
#                                     title   type  release_year  \
# 0     Five Came Back: The Reference Films   SHOW          1945
# 1                             Taxi Driver  MOVIE          1976
# 2         Monty Python and the Holy Grail  MOVIE          1975
# 3                           Life of Brian  MOVIE          1979
# 4                            The Exorcist  MOVIE          1973
# ...                                   ...    ...           ...
# 5801                            Fine Wine  MOVIE          2021
# 5802                       Edis Starlight  MOVIE          2021
# 5803                                Clash  MOVIE          2021
# 5804                       Shadow Parties  MOVIE          2021
# 5805   Mighty Little Bheem: Kite Festival   SHOW          2021
#
#      age_certification  runtime                             genres  \
# 0                TV-MA       48                  ['documentation']
# 1                    R      113                 ['crime', 'drama']
# ...

# %%
#How many rows and columns are there?
df.shape
# Out:
# (5806, 11)

# %%
#Display:
#* column names
#* datatype of every column
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 5805 non-null   object
#  1   type                  5806 non-null   object
#  2   release_year          5806 non-null   int64
#  3   age_certification     3196 non-null   object
#  4   runtime               5806 non-null   int64
#  5   genres                5806 non-null   object
#  6   production_countries  5806 non-null   object
#  7   seasons               2047 non-null   float64
#  8   imdb_id               5362 non-null   object
#  9   imdb_score            5283 non-null   float64
#  10  imdb_votes            5267 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 499.1+ KB

# %%
#How many missing values are present in every column?
df.isnull().sum()
# Out:
# title                      1
# type                       0
# release_year               0
# age_certification       2610
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3759
# imdb_id                  444
# imdb_score               523
# imdb_votes               539
# dtype: int64

# %%
#How many Movies and how many TV Shows are there?
type=df.groupby('type').count()
type
# Out:
#        title  release_year  age_certification  runtime  genres  \
# type
# MOVIE   3758          3759               1406     3759    3759
# SHOW    2047          2047               1790     2047    2047
#
#        production_countries  seasons  imdb_id  imdb_score  imdb_votes
# type
# MOVIE                  3759        0     3451        3407        3391
# SHOW                   2047     2047     1911        1876        1876

# %%
 df['type'].value_counts()
# Out:
# type
# MOVIE    3759
# SHOW     2047
# Name: count, dtype: int64

# %%
#Find all movies released in 2020.
df[(df['release_year'] == 2020) & (df['type'] == 'MOVIE')]
# Out:
#                                       title   type  release_year  \
# 3187                             The Rental  MOVIE          2020
# 3191                               365 Days  MOVIE          2020
# 3210          I'm Thinking of Ending Things  MOVIE          2020
# 3213                 The Devil All the Time  MOVIE          2020
# 3215                     My Octopus Teacher  MOVIE          2020
# ...                                     ...    ...           ...
# 4816                               One Take  MOVIE          2020
# 4818                    #FriendButMarried 2  MOVIE          2020
# 4820                         Girl's Revenge  MOVIE          2020
# 4823  Story of Kale: When Someone's in Love  MOVIE          2020
# 4827                                  Milea  MOVIE          2020
#
#      age_certification  runtime                                    genres  \
# 3187                 R       88           ['thriller', 'drama', 'horror']
# ...

# %%
#How many unique countries are present?
df['production_countries'].nunique()
#->answer not coming right because same country its reading string despite ind and us have came before its treating it new string and 
#also some missing values too
# Out:
# 449

# %%
df.sample(10)
# Out:
#                      title   type  release_year age_certification  runtime  \
# 2606          Larva Island   SHOW          2018             TV-Y7        8
# 3240    The Social Dilemma  MOVIE          2020             PG-13       94
# 3921           Pup Academy   SHOW          2019              TV-Y       26
# 1218      The Last Kingdom   SHOW          2015             TV-MA       55
# 3667  Amy Schumer: Growing  MOVIE          2019               NaN       61
# 1188   Mumbai Delhi Mumbai  MOVIE          2014                PG      120
# 1137             Refugiado  MOVIE          2014                 R       95
# 286          Love Actually  MOVIE          2003                 R      139
# 5282           This Is Pop   SHOW          2021             TV-MA       44
# 2291          Carrie Pilby  MOVIE          2017               NaN       98
#
#                                                  genres production_countries  \
# ...

# %%
df['production_countries'].dropna()
#here null values are not truly null rather []
# Out:
# 0             ['US']
# 1             ['US']
# 2             ['GB']
# 3             ['GB']
# 4             ['US']
#             ...
# 5801          ['NG']
# 5802              []
# 5803    ['NG', 'CA']
# 5804              []
# 5805              []
# Name: production_countries, Length: 5806, dtype: object

# %%
df['production_countries'].value_counts()
# Out:
# production_countries
# ['US']                      1950
# ['IN']                       605
# ['JP']                       266
# []                           232
# ['GB']                       219
#                             ...
# ['PR', 'US', 'GB', 'CN']       1
# ['GB', 'US', 'FR']             1
# ['IT', 'ES', 'FR']             1
# ['GB', 'US', 'CZ']             1
# ['NG', 'CA']                   1
# Name: count, Length: 449, dtype: int64

# %%
df = df[df['production_countries'] != '[]']

# %%
df['production_countries'].value_counts()
# Out:
# production_countries
# ['US']                      1950
# ['IN']                       605
# ['JP']                       266
# ['GB']                       219
# ['KR']                       210
#                             ...
# ['PR', 'US', 'GB', 'CN']       1
# ['GB', 'US', 'FR']             1
# ['IT', 'ES', 'FR']             1
# ['GB', 'US', 'CZ']             1
# ['NG', 'CA']                   1
# Name: count, Length: 448, dtype: int64

# %%
new_df=df['production_countries'].str.split(',', expand=True)
new_df.head()
#->problem is its not comma separated rather in list
# Out:
#         0     1     2     3     4     5     6
# 0  ['US']  None  None  None  None  None  None
# 1  ['US']  None  None  None  None  None  None
# 2  ['GB']  None  None  None  None  None  None
# 3  ['GB']  None  None  None  None  None  None
# 4  ['US']  None  None  None  None  None  None

# %%
df['production_countries'].head(5)
# Out:
# 0    ['US']
# 1    ['US']
# 2    ['GB']
# 3    ['GB']
# 4    ['US']
# Name: production_countries, dtype: object

# %%
from ast import literal_eval

df['production_countries'] = df['production_countries'].apply(literal_eval)
#to convert into python list
# Out:
# /var/folders/1b/4rx0vcfj7h19jk43wjg2_b7r0000gn/T/ipykernel_59963/344093610.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['production_countries'] = df['production_countries'].apply(literal_eval)

# %%
countries=df['production_countries'].explode()

# %%
countries.nunique()
# Out:
# 107

# %%
#Which country has produced the highest number of Netflix titles?
countries.value_counts()
# Out:
# production_countries
# US         2327
# IN          629
# GB          406
# JP          291
# FR          248
#            ...
# DZ            1
# Lebanon       1
# BF            1
# BS            1
# FO            1
# Name: count, Length: 107, dtype: int64

# %%
#Which year had the maximum content added?
df['release_year'].value_counts(ascending=False)
# Out:
# release_year
# 2019    800
# 2020    749
# 2018    748
# 2021    705
# 2017    571
#        ...
# 1974      1
# 1959      1
# 1962      1
# 1978      1
# 1945      1
# Name: count, Length: 67, dtype: int64

# %%
df
# Out:
#                                     title   type  release_year  \
# 0     Five Came Back: The Reference Films   SHOW          1945
# 1                             Taxi Driver  MOVIE          1976
# 2         Monty Python and the Holy Grail  MOVIE          1975
# 3                           Life of Brian  MOVIE          1979
# 4                            The Exorcist  MOVIE          1973
# ...                                   ...    ...           ...
# 5798                        Time to Dance  MOVIE          2021
# 5799                           HQ Barbers   SHOW          2021
# 5800          Momshies! Your Soul is Mine  MOVIE          2021
# 5801                            Fine Wine  MOVIE          2021
# 5803                                Clash  MOVIE          2021
#
#      age_certification  runtime                 genres production_countries  \
# 0                TV-MA       48      ['documentation']                 [US]
# ...

# %%
#Find all movies that have an IMDb rating greater than 8.5 and have received more than 50,000 votes.

df[(df['type']=='MOVIE') & (df['imdb_score']>8.5) & (df['imdb_votes']>50000)]
# Out:
#                    title   type  release_year age_certification  runtime  \
# 108         Forrest Gump  MOVIE          1994             PG-13      142
# 111  Saving Private Ryan  MOVIE          1998                 R      169
# 260            Inception  MOVIE          2010             PG-13      148
#
#                                        genres production_countries  seasons  \
# 108            ['drama', 'romance', 'comedy']                 [US]      NaN
# 111                          ['drama', 'war']                 [US]      NaN
# 260  ['scifi', 'music', 'thriller', 'action']             [GB, US]      NaN
#
#        imdb_id  imdb_score  imdb_votes
# 108  tt0109830         8.8   1994599.0
# 111  tt0120815         8.6   1346020.0
# 260  tt1375666         8.8   2268288.0

# %%
#Find the top 20 highest-rated movies released after 2015.
df[(df['release_year']>2015) & (df['type']=='MOVIE')].sort_values(by='imdb_score',ascending=False).head(20)
# Out:
#                                                   title   type  release_year  \
# 3352           David Attenborough: A Life on Our Planet  MOVIE          2020
# 2814                                  C/o Kancharapalem  MOVIE          2018
# 4944                                 Bo Burnham: Inside  MOVIE          2021
# 4252                                      Rubaru Roshni  MOVIE          2019
# 5512                            In Our Mothers' Gardens  MOVIE          2021
# 3062                              Merku Thodarchi Malai  MOVIE          2018
# 3804  Best Wishes, Warmest Regards: A Schitt's Creek...  MOVIE          2020
# 4143          Emicida: AmarElo - It's All for Yesterday  MOVIE          2020
# 2298                            Springsteen On Broadway  MOVIE          2018
# 4621                                              K. D.  MOVIE          2019
# 2946                      Ani... Dr. Kashinath Ghanekar  MOVIE          2018
# ...

# %%
#Find movies whose runtime is between 90 and 120 minutes.
new_df=df[df['runtime']>90]
new_df[new_df['runtime']<120]
new_df[new_df['type']=='MOVIE']
# Out:
#                                 title   type  release_year age_certification  \
# 1                         Taxi Driver  MOVIE          1976                 R
# 2     Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                       Life of Brian  MOVIE          1979                 R
# 4                        The Exorcist  MOVIE          1973                 R
# 6                         Dirty Harry  MOVIE          1971                 R
# ...                               ...    ...           ...               ...
# 5795              The Heartbreak Club  MOVIE          2021               NaN
# 5797             Princess 'Daya'Reese  MOVIE          2021               NaN
# 5798                    Time to Dance  MOVIE          2021               NaN
# 5800      Momshies! Your Soul is Mine  MOVIE          2021               NaN
# 5801                        Fine Wine  MOVIE          2021               NaN
#
# ...

# %%
#For every type, calculate in one statement:

#* Count
#* Mean IMDb score
#* Mean runtime
#* Maximum IMDb score
#* Minimum IMDb score
#* Total IMDb votes
type_yup=df.groupby('type')
type_yup['imdb_score'].mean(numeric_only=True)
# Out:
# type
# MOVIE    6.269091
# SHOW     7.034528
# Name: imdb_score, dtype: float64

# %%
type_yup['type'].count()
# Out:
# type
# MOVIE    3607
# SHOW     1967
# Name: type, dtype: int64

# %%
type_yup['runtime'].mean(numeric_only=True)
# Out:
# type
# MOVIE    99.899917
# SHOW     39.098119
# Name: runtime, dtype: float64

# %%
type_yup['imdb_score'].max(numeric_only=True)
# Out:
# type
# MOVIE    9.0
# SHOW     9.5
# Name: imdb_score, dtype: float64

# %%
type_yup['imdb_score'].min(numeric_only=True)
# Out:
# type
# MOVIE    1.5
# SHOW     1.6
# Name: imdb_score, dtype: float64

# %%
type_yup['imdb_votes'].sum()
# Out:
# type
# MOVIE    90429687.0
# SHOW     32742073.0
# Name: imdb_votes, dtype: float64

# %%
#Find the top 5 release years having the highest average IMDb score.
ab=df.groupby('release_year')

# %%
ab['imdb_score'].mean().sort_values(ascending=False).head(5)
# Out:
# release_year
# 1985    8.00
# 1969    7.85
# 1964    7.80
# 1967    7.70
# 1963    7.60
# Name: imdb_score, dtype: float64

# %%
#For every certification find

#* Average runtime
#* Number of titles
df['age_certification'].value_counts()
# Out:
# age_certification
# TV-MA    823
# R        572
# TV-14    458
# PG-13    437
# PG       244
# TV-PG    176
# G        118
# TV-Y7    107
# TV-Y      94
# TV-G      75
# NC-17     14
# Name: count, dtype: int64

# %%
df['age_certification'].isnull().sum()
# Out:
# np.int64(2456)

# %%
df = df.dropna(subset=['age_certification'])

# %%
df['age_certification'].isnull().sum()
# Out:
# np.int64(0)

# %%
cd=df.groupby('age_certification')

# %%
cd['runtime'].mean()
# Out:
# age_certification
# G         95.322034
# NC-17     95.214286
# PG       104.762295
# PG-13    108.231121
# R        105.666084
# TV-14     41.925764
# TV-G      26.613333
# TV-MA     43.614824
# TV-PG     35.534091
# TV-Y      16.755319
# TV-Y7     22.261682
# Name: runtime, dtype: float64

# %%
cd['type'].value_counts()
# Out:
# age_certification  type
# G                  MOVIE    118
# NC-17              MOVIE     14
# PG                 MOVIE    244
# PG-13              MOVIE    437
# R                  MOVIE    572
# TV-14              SHOW     458
# TV-G               SHOW      75
# TV-MA              SHOW     823
# TV-PG              SHOW     176
# TV-Y               SHOW      94
# TV-Y7              SHOW     107
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                  title   type  release_year age_certification  \
# 0  Five Came Back: The Reference Films   SHOW          1945             TV-MA
# 1                          Taxi Driver  MOVIE          1976                 R
# 2      Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                        Life of Brian  MOVIE          1979                 R
# 4                         The Exorcist  MOVIE          1973                 R
#
#    runtime                 genres production_countries  seasons    imdb_id  \
# 0       48      ['documentation']                 [US]      1.0        NaN
# 1      113     ['crime', 'drama']                 [US]      NaN  tt0075314
# 2       91  ['comedy', 'fantasy']                 [GB]      NaN  tt0071853
# 3       94             ['comedy']                 [GB]      NaN  tt0079470
# 4      133             ['horror']                 [US]      NaN  tt0070047
#
#    imdb_score  imdb_votes
# ...

# %%
#Find the highest-rated movie for every release year.
new_df=df[df['type']=='MOVIE']

# %%
idx = new_df.groupby('release_year')['imdb_score'].idxmax()

# %%
new_df.loc[idx]
# Out:
#                                          title   type  release_year  \
# 7                                 My Fair Lady  MOVIE          1964
# 10                           The Professionals  MOVIE          1966
# 9                             Bonnie and Clyde  MOVIE          1967
# 6                                  Dirty Harry  MOVIE          1971
# 19                                         FTA  MOVIE          1972
# 4                                 The Exorcist  MOVIE          1973
# 2              Monty Python and the Holy Grail  MOVIE          1975
# 1                                  Taxi Driver  MOVIE          1976
# 18                            Hitler: A Career  MOVIE          1977
# 13              Richard Pryor: Live in Concert  MOVIE          1979
# 14                             The Long Riders  MOVIE          1980
# 63                                Endless Love  MOVIE          1981
# 72     Monty Python Live at the Hollywood Bowl  MOVIE          1982
# ...

# %%
#Find top 15 genres.
df['genres'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['genres'].value_counts()
# Out:
# genres
# ['comedy']                                      167
# ['drama']                                       131
# ['documentation']                               106
# ['reality']                                      88
# ['comedy', 'drama']                              79
#                                                ...
# ['drama', 'fantasy', 'action']                    1
# ['drama', 'history', 'war', 'documentation']      1
# ['thriller', 'fantasy', 'horror', 'drama']        1
# ['scifi', 'comedy', 'animation', 'fantasy']       1
# ['music', 'romance', 'comedy']                    1
# Name: count, Length: 1222, dtype: int64

# %%
new_df=df['genres'].str.split(',', expand=True)
new_df.head()
# Out:
#                    0            1     2     3     4     5     6     7     8
# 0  ['documentation']         None  None  None  None  None  None  None  None
# 1           ['crime'     'drama']  None  None  None  None  None  None  None
# 2          ['comedy'   'fantasy']  None  None  None  None  None  None  None
# 3         ['comedy']         None  None  None  None  None  None  None  None
# 4         ['horror']         None  None  None  None  None  None  None  None

# %%
from ast import literal_eval

df['genres'] = df['genres'].apply(literal_eval)
#to convert into python list
# Out:
# /var/folders/1b/4rx0vcfj7h19jk43wjg2_b7r0000gn/T/ipykernel_59963/2804744302.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].apply(literal_eval)

# %%
new_df = df.explode('genres')

# %%
new_df.groupby('genres').size().sort_values(ascending=False).head(15)
# Out:
# genres
# drama            1667
# comedy           1179
# thriller          739
# action            724
# crime             582
# romance           505
# animation         496
# fantasy           484
# scifi             482
# family            431
# documentation     407
# horror            242
# european          212
# reality           166
# history           144
# dtype: int64

# %%
#Find average IMDb score for each genre.
new_df.groupby('genres')['imdb_score'].mean(numeric_only=True)
# Out:
# genres
# action           6.668839
# animation        6.868201
# comedy           6.660243
# crime            6.895979
# documentation    7.111538
# drama            6.924334
# european         6.919024
# family           6.466038
# fantasy          6.756276
# history          7.280556
# horror           6.322650
# music            6.830275
# reality          6.545223
# romance          6.730219
# scifi            6.703922
# sport            6.795575
# thriller         6.624448
# war              7.147475
# western          6.915152
# Name: imdb_score, dtype: float64

# %%
#Find average runtime for each genre.
new_df.groupby('genres')['runtime'].mean(numeric_only=True)
# Out:
# genres
# action           71.928177
# animation        39.689516
# comedy           65.114504
# crime            76.429553
# documentation    60.837838
# drama            75.602280
# european         78.882075
# family           52.125290
# fantasy          59.762397
# history          80.875000
# horror           73.355372
# music            73.360360
# reality          41.722892
# romance          84.455446
# scifi            54.149378
# sport            76.716814
# thriller         82.331529
# war              86.920792
# western          94.228571
# Name: runtime, dtype: float64

# %%
#Which genre has

#highest votes
#highest runtime
#highest rating



a_df=new_df.groupby('genres')['imdb_votes'].mean(numeric_only=True)
a_df.idxmax()
# Out:
# 'western'

# %%
b_df=new_df.groupby('genres')['runtime'].mean(numeric_only=True)
b_df.idxmax()
# Out:
# 'western'

# %%
c_df=new_df.groupby('genres')['imdb_score'].mean(numeric_only=True)
c_df.idxmax()
# Out:
# 'history'

# %%
result = {
    'Metric': [
        'Highest Avg Votes',
        'Highest Avg Runtime',
        'Highest Avg Rating'
    ],
    'Genre': [
        a_df.idxmax(),
        b_df.idxmax(),
        c_df.idxmax()
    ]
}

result_df = pd.DataFrame(result)
result_df
# Out:
#                 Metric    Genre
# 0    Highest Avg Votes  western
# 1  Highest Avg Runtime  western
# 2   Highest Avg Rating  history

# %%
#Create a table

#| Column | Missing % |

#sorted descending.
df.isnull().sum()
# Out:
# title                      0
# type                       0
# release_year               0
# age_certification          0
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 1385
# imdb_id                  153
# imdb_score               177
# imdb_votes               186
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# title                    0.000000
# type                     0.000000
# release_year             0.000000
# age_certification        0.000000
# runtime                  0.000000
# genres                   0.000000
# production_countries     0.000000
# seasons                 44.419500
# imdb_id                  4.906992
# imdb_score               5.676716
# imdb_votes               5.965362
# dtype: float64

# %%
missing_df = ((df.isnull().sum() / len(df)) * 100).reset_index()
missing_df
#convert to dataframe
# Out:
#                    index          0
# 0                  title   0.000000
# 1                   type   0.000000
# 2           release_year   0.000000
# 3      age_certification   0.000000
# 4                runtime   0.000000
# 5                 genres   0.000000
# 6   production_countries   0.000000
# 7                seasons  44.419500
# 8                imdb_id   4.906992
# 9             imdb_score   5.676716
# 10            imdb_votes   5.965362

# %%
missing_df.columns = ['Column', 'Missing %']

# %%
missing_df.sort_values(by='Missing %', ascending=False)
# Out:
#                   Column  Missing %
# 7                seasons  44.419500
# 10            imdb_votes   5.965362
# 9             imdb_score   5.676716
# 8                imdb_id   4.906992
# 0                  title   0.000000
# 1                   type   0.000000
# 2           release_year   0.000000
# 3      age_certification   0.000000
# 4                runtime   0.000000
# 5                 genres   0.000000
# 6   production_countries   0.000000

# %%
#Replace missing certification with

#Unknown

#without changing original dataframe.
df['age_certification'].isnull().sum()
# Out:
# np.int64(0)

# %%
new = df.copy()

# %%
new['age_certification'] = new['age_certification'].fillna('Unknown')

# %%
new['age_certification'].isin(['[]']).sum()
# Out:
# np.int64(0)

# %%
#Suppose runtime has missing values.Fill them with median runtime within each type.
df['runtime'].isnull().sum()
# Out:
# np.int64(0)

# %%
new_df = df.copy()

new_df['runtime'] = new_df['runtime'].fillna(
    new_df.groupby('type')['runtime'].transform('median')
)

# %%
new_df
# Out:
#                                           title   type  release_year  \
# 0           Five Came Back: The Reference Films   SHOW          1945
# 1                                   Taxi Driver  MOVIE          1976
# 2               Monty Python and the Holy Grail  MOVIE          1975
# 3                                 Life of Brian  MOVIE          1979
# 4                                  The Exorcist  MOVIE          1973
# ...                                         ...    ...           ...
# 5783  Dad Stop Embarrassing Me - The Afterparty  MOVIE          2021
# 5785                              Pitta Kathalu   SHOW          2021
# 5794                            Masameer County   SHOW          2021
# 5796                                The Big Day   SHOW          2021
# 5799                                 HQ Barbers   SHOW          2021
#
#      age_certification  runtime              genres production_countries  \
# ...

# %%
#Find

#mean
#std
#variance
#median
#25 percentile
#75 percentile of imdb score
numpy_df=df['imdb_score'].to_numpy()

# %%
np.mean(numpy_df)
# Out:
# np.float64(nan)

# %%
df['imdb_score'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3118 entries, 0 to 5799
# Series name: imdb_score
# Non-Null Count  Dtype
# --------------  -----
# 2941 non-null   float64
# dtypes: float64(1)
# memory usage: 48.7 KB

# %%
df_cleaned = df.dropna()

# %%
numpy_df=df_cleaned['imdb_score'].to_numpy()

# %%
np.mean(numpy_df)
# Out:
# np.float64(7.049907692307692)

# %%
np.std(numpy_df)
# Out:
# np.float64(1.043474222497974)

# %%
np.var(numpy_df)
# Out:
# np.float64(1.0888384530177515)

# %%
np.median(numpy_df)
# Out:
# np.float64(7.2)

# %%
np.percentile(numpy_df,25)
# Out:
# np.float64(6.5)

# %%
np.percentile(numpy_df,75)
# Out:
# np.float64(7.8)

# %%
#Using Boolean Indexing
#Find percentage of movies having score > mean score
qw=numpy_df[numpy_df>np.mean(numpy_df)]

# %%
np.size(qw)/len(numpy_df)*100
# Out:
# 55.44615384615385

# %%
#Normalize runtime manually using NumPy.
   # (x - x.min()) / (x.max() - x.min())
np.(lambda x: x)
(numpy_df.arr[x]-np.min(numpy_df))/(np.max(numpy_df)-np.min(numpy_df))
# Out:
#   Cell In[449], line 3
#     np.(lambda x: x)
#        ^
# SyntaxError: invalid syntax
